# %% [markdown]
# ## Gathering Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import requests
import os
import tweepy
import json
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df_arc= pd.read_csv('twitter-archive-enhanced.csv')

# %%
print(df_arc.shape[0])
df_arc.head()
# Out:
# 2356
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
folder_name = 'image-predictions'
if not os.path.exists(folder_name):
    os.makedirs(folder_name)
url= 'https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv'
response = requests.get(url)
print(response)
with open(os.path.join(folder_name,url.split('/')[-1]),mode='wb') as file:
    file.write(response.content)
# downloading the prediction file
# Out:
# <Response [200]>

# %%
os.listdir(folder_name)
# Out:
# ['.ipynb_checkpoints', 'image-predictions.tsv']

# %%
df_image = pd.read_csv('image-predictions/image-predictions.tsv',sep='\t') #reading the prediction file
df_image.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %% [markdown]
# #### Note that i couldn't get access to Twitter API

# %%
df_json= pd.read_json('tweet-json.txt',lines=True) #reading json file

# %%
df_json.head()
# Out:
#    contributors  coordinates          created_at display_text_range  \
# 0           NaN          NaN 2017-08-01 16:23:56            [0, 85]
# 1           NaN          NaN 2017-08-01 00:17:27           [0, 138]
# 2           NaN          NaN 2017-07-31 00:18:03           [0, 121]
# 3           NaN          NaN 2017-07-30 15:58:51            [0, 79]
# 4           NaN          NaN 2017-07-29 16:00:24           [0, 138]
#
#                                             entities  \
# 0  {'hashtags': [], 'symbols': [], 'user_mentions...
# 1  {'hashtags': [], 'symbols': [], 'user_mentions...
# 2  {'hashtags': [], 'symbols': [], 'user_mentions...
# 3  {'hashtags': [], 'symbols': [], 'user_mentions...
# 4  {'hashtags': [{'text': 'BarkWeek', 'indices': ...
#
#                                    extended_entities  favorite_count  \
# 0  {'media': [{'id': 892420639486877696, 'id_str'...           39467
# 1  {'media': [{'id': 892177413194625024, 'id_str'...           33819
# ...

# %% [markdown]
# ## Assessing Data

# %%
df_arc.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# ...

# %%
df_arc[df_arc.retweeted_status_id.notnull()]
# Out:
#                 tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 19    888202515573088257                    NaN                  NaN
# 32    886054160059072513                    NaN                  NaN
# 36    885311592912609280                    NaN                  NaN
# 68    879130579576475649                    NaN                  NaN
# 73    878404777348136964                    NaN                  NaN
# 74    878316110768087041                    NaN                  NaN
# 78    877611172832227328                    NaN                  NaN
# 91    874434818259525634                    NaN                  NaN
# 95    873697596434513921                    NaN                  NaN
# 97    873337748698140672                    NaN                  NaN
# 101   872668790621863937                    NaN                  NaN
# 109   871166179821445120                    NaN                  NaN
# 118   869988702071779329                    NaN                  NaN
# ...

# %%
df_arc.nunique()
# Out:
# tweet_id                      2356
# in_reply_to_status_id           77
# in_reply_to_user_id             31
# timestamp                     2356
# source                           4
# text                          2356
# retweeted_status_id            181
# retweeted_status_user_id        25
# retweeted_status_timestamp     181
# expanded_urls                 2218
# rating_numerator                40
# rating_denominator              18
# name                           957
# doggo                            2
# floofer                          2
# pupper                           2
# puppo                            2
# dtype: int64

# %%
df_arc.source.value_counts()
# Out:
# <a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>     2221
# <a href="http://vine.co" rel="nofollow">Vine - Make a Scene</a>                          91
# <a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>                       33
# <a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>      11
# Name: source, dtype: int64

# %%
df_arc.T
# Out:
#                                                                          0     \
# tweet_id                                                   892420643555336193
# in_reply_to_status_id                                                     NaN
# in_reply_to_user_id                                                       NaN
# timestamp                                           2017-08-01 16:23:56 +0000
# source                      <a href="http://twitter.com/download/iphone" r...
# text                        This is Phineas. He's a mystical boy. Only eve...
# retweeted_status_id                                                       NaN
# retweeted_status_user_id                                                  NaN
# retweeted_status_timestamp                                                NaN
# expanded_urls               https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                           13
# ...

# %%
df_image.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# ...

# %%
df_image.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
df_image.nunique()
# Out:
# tweet_id    2075
# jpg_url     2009
# img_num        4
# p1           378
# p1_conf     2006
# p1_dog         2
# p2           405
# p2_conf     2004
# p2_dog         2
# p3           408
# p3_conf     2006
# p3_dog         2
# dtype: int64

# %%
df_image.T
# Out:
#                                                      0     \
# tweet_id                               666020888022790149
# jpg_url   https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# img_num                                                 1
# p1                                 Welsh_springer_spaniel
# p1_conf                                          0.465074
# p1_dog                                               True
# p2                                                 collie
# p2_conf                                          0.156665
# p2_dog                                               True
# p3                                      Shetland_sheepdog
# p3_conf                                         0.0614285
# p3_dog                                               True
#
#                                                      1     \
# tweet_id                               666029285002620928
# jpg_url   https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# ...

# %%
df_image.p1.value_counts()
# Out:
# golden_retriever             150
# Labrador_retriever           100
# Pembroke                      89
# Chihuahua                     83
# pug                           57
# chow                          44
# Samoyed                       43
# toy_poodle                    39
# Pomeranian                    38
# malamute                      30
# cocker_spaniel                30
# French_bulldog                26
# miniature_pinscher            23
# Chesapeake_Bay_retriever      23
# seat_belt                     22
# Siberian_husky                20
# German_shepherd               20
# Staffordshire_bullterrier     20
# Cardigan                      19
# web_site                      19
# Eskimo_dog                    18
# beagle                        18
# Maltese_dog                   18
# Shetland_sheepdog             18
# teddy                         18
# Lakeland_terrier              17
# Shih-Tzu                      17
# Rottweiler                    17
# ...

# %%
df_image[df_image['p1'] == 'seat_belt']
# Out:
#                 tweet_id                                            jpg_url  \
# 43    666776908487630848    https://pbs.twimg.com/media/CUDeDoWUYAAD-EM.jpg
# 108   667878741721415682    https://pbs.twimg.com/media/CUTILFiWcAE8Rle.jpg
# 198   669625907762618368    https://pbs.twimg.com/media/CUr9NjgU8AEpf5w.jpg
# 235   670427002554466305    https://pbs.twimg.com/media/CU3VzVwWwAAAsst.jpg
# 522   676582956622721024    https://pbs.twimg.com/media/CWO0m8tUwAAB901.jpg
# 551   677557565589463040    https://pbs.twimg.com/media/CWcrAVQWEAA6QMp.jpg
# 577   678740035362037760    https://pbs.twimg.com/media/CWtede2WIAAF_AJ.jpg
# 642   681339448655802368    https://pbs.twimg.com/media/CXSanNkWkAAqR9M.jpg
# 657   682303737705140231    https://pbs.twimg.com/media/CXgHoLnWAAA8i52.jpg
# 740   687312378585812992    https://pbs.twimg.com/media/CYnS9VWW8AAeR8m.jpg
# 843   695064344191721472  https://pbs.twimg.com/ext_tw_video_thumb/69506...
# ...

# %%
df_json.T
# Out:
#                                                                             0     \
# contributors                                                                 NaN
# coordinates                                                                  NaN
# created_at                                                   2017-08-01 16:23:56
# display_text_range                                                       [0, 85]
# entities                       {'hashtags': [], 'symbols': [], 'user_mentions...
# extended_entities              {'media': [{'id': 892420639486877696, 'id_str'...
# favorite_count                                                             39467
# favorited                                                                  False
# full_text                      This is Phineas. He's a mystical boy. Only eve...
# geo                                                                          NaN
# id                                                            892420643555336193
# ...

# %%
df_json.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 31 columns):
# contributors                     0 non-null float64
# coordinates                      0 non-null float64
# created_at                       2354 non-null datetime64[ns]
# display_text_range               2354 non-null object
# entities                         2354 non-null object
# extended_entities                2073 non-null object
# favorite_count                   2354 non-null int64
# favorited                        2354 non-null bool
# full_text                        2354 non-null object
# geo                              0 non-null float64
# id                               2354 non-null int64
# id_str                           2354 non-null int64
# in_reply_to_screen_name          78 non-null object
# in_reply_to_status_id            78 non-null float64
# in_reply_to_status_id_str        78 non-null float64
# ...

# %% [markdown]
# #### Quality
#
# - Changing the type of tweet_id.
# - Changing the type of timestamp.
# - None considered as a dog name (need to be changed)
# - there are some retweeted values which considered as duplicate values.
# - missing data in expanded_urls.
# - wrong dog names like 'a' and 'this'
# - there are some duplicate jpg_url
# - changing the name of id column in df_json to tweet_id
#
# ##### Tidiness
#
# - combining the doggo, floofer, pupper and puppo columns into one column.
# - joining the three data frames.

# %% [markdown]
# ## Cleaning Data

# %%
df_arc.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_arc.tweet_id = df_arc.tweet_id.astype(str) #changing the type of tweet_id.

# %%
df_arc['timestamp'] =  pd.to_datetime(df_arc['timestamp']) #changing the type of timestamp.

# %%
df_arc=df_arc.replace('None', np.nan) # fixing the None issue

# %%
df_arc.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                   timestamp  \
# 0 2017-08-01 16:23:56+00:00
# 1 2017-08-01 00:17:27+00:00
# 2 2017-07-31 00:18:03+00:00
# 3 2017-07-30 15:58:51+00:00
# 4 2017-07-29 16:00:24+00:00
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
# ...

# %%
df_arc= df_arc[df_arc.retweeted_status_id.isnull()]    
df_arc= df_arc[df_arc.in_reply_to_status_id.isnull()]
df_arc= df_arc[df_arc.expanded_urls.notnull()] #removing the retweeted values and the nulls url.

# %%
df_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2094 non-null object
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     2094 non-null datetime64[ns, UTC]
# source                        2094 non-null object
# text                          2094 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null object
# expanded_urls                 2094 non-null object
# rating_numerator              2094 non-null int64
# rating_denominator            2094 non-null int64
# name                          1494 non-null object
# doggo                         83 non-null object
# floofer                       10 non-null object
# pupper                        229 non-null object
# ...

# %%
df_arc['dog_stage'] = df_arc[df_arc.columns[-4:]].apply(
    lambda x: ','.join(x.dropna().astype(str)),
    axis=1
) #creating one column for the dog stage

# %%
df_arc.dog_stage.value_counts()
#value counts the dog stages.
# Out:
#                  1759
# pupper            220
# doggo              72
# puppo              23
# floofer             9
# doggo,pupper        9
# doggo,puppo         1
# doggo,floofer       1
# Name: dog_stage, dtype: int64

# %%
df_arc=df_arc.replace('', np.nan) # fixing the None issue 
df_arc.head()
df_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 18 columns):
# tweet_id                      2094 non-null object
# in_reply_to_status_id         0 non-null float64
# in_reply_to_user_id           0 non-null float64
# timestamp                     2094 non-null datetime64[ns, UTC]
# source                        2094 non-null object
# text                          2094 non-null object
# retweeted_status_id           0 non-null float64
# retweeted_status_user_id      0 non-null float64
# retweeted_status_timestamp    0 non-null float64
# expanded_urls                 2094 non-null object
# rating_numerator              2094 non-null int64
# rating_denominator            2094 non-null int64
# name                          1494 non-null object
# doggo                         83 non-null object
# floofer                       10 non-null object
# pupper                        229 non-null object
# ...

# %%
df_arc.drop(['in_reply_to_status_id','in_reply_to_user_id','retweeted_status_id','retweeted_status_user_id','retweeted_status_timestamp','doggo','floofer', 'pupper','puppo'], axis=1, inplace= True)
# drop some of the unnecessary columns 
df_arc.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2094 entries, 0 to 2355
# Data columns (total 9 columns):
# tweet_id              2094 non-null object
# timestamp             2094 non-null datetime64[ns, UTC]
# source                2094 non-null object
# text                  2094 non-null object
# expanded_urls         2094 non-null object
# rating_numerator      2094 non-null int64
# rating_denominator    2094 non-null int64
# name                  1494 non-null object
# dog_stage             335 non-null object
# dtypes: datetime64[ns, UTC](1), int64(2), object(6)
# memory usage: 163.6+ KB

# %%
df_image.tweet_id = df_image.tweet_id.astype(str) #changing the type of tweet_id.

# %%
df_image = df_image[~df_image.jpg_url.duplicated()] #removing the duplicated urls.

# %%
df_json.rename(columns={'id': 'tweet_id'}, inplace=True)
df_json.tweet_id = df_json.tweet_id.astype(str) #changing the name and type of the id to tweet_id as a type str.

# %%
df_all = df_arc.merge(df_image, on='tweet_id', how='inner') #merging the DFs

# %%
df_all = df_all.merge(df_json, on='tweet_id', how='inner') #merging the DFs
df_all.head()
# Out:
#              tweet_id                 timestamp  \
# 0  892420643555336193 2017-08-01 16:23:56+00:00
# 1  892177421306343426 2017-08-01 00:17:27+00:00
# 2  891815181378084864 2017-07-31 00:18:03+00:00
# 3  891689557279858688 2017-07-30 15:58:51+00:00
# 4  891327558926688256 2017-07-29 16:00:24+00:00
#
#                                             source_x  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  \
# 0  This is Phineas. He's a mystical boy. Only eve...
# 1  This is Tilly. She's just checking pup on you....
# 2  This is Archie. He is a rare Norwegian Pouncin...
# 3  This is Darla. She commenced a snooze mid meal...
# 4  This is Franklin. He would like you to stop ca...
#
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 1970
# Data columns (total 50 columns):
# tweet_id                         1971 non-null object
# timestamp                        1971 non-null datetime64[ns, UTC]
# source_x                         1971 non-null object
# text                             1971 non-null object
# expanded_urls                    1971 non-null object
# rating_numerator                 1971 non-null int64
# rating_denominator               1971 non-null int64
# name                             1447 non-null object
# dog_stage                        303 non-null object
# jpg_url                          1971 non-null object
# img_num                          1971 non-null int64
# p1                               1971 non-null object
# p1_conf                          1971 non-null float64
# p1_dog                           1971 non-null bool
# p2                               1971 non-null object
# ...

# %%
df_all.drop(['contributors','coordinates','geo','in_reply_to_screen_name','in_reply_to_status_id','in_reply_to_status_id_str','in_reply_to_user_id','in_reply_to_user_id_str','quoted_status' ,'quoted_status_id','quoted_status_id' ,'retweeted_status' ], axis=1, inplace= True)
# drop the unnecessary columns 
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 1970
# Data columns (total 39 columns):
# tweet_id                         1971 non-null object
# timestamp                        1971 non-null datetime64[ns, UTC]
# source_x                         1971 non-null object
# text                             1971 non-null object
# expanded_urls                    1971 non-null object
# rating_numerator                 1971 non-null int64
# rating_denominator               1971 non-null int64
# name                             1447 non-null object
# dog_stage                        303 non-null object
# jpg_url                          1971 non-null object
# img_num                          1971 non-null int64
# p1                               1971 non-null object
# p1_conf                          1971 non-null float64
# p1_dog                           1971 non-null bool
# p2                               1971 non-null object
# ...

# %%
df_all.drop(['place','quoted_status_id_str'], axis=1, inplace= True) # drop some of the unnecessary columns 
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 1970
# Data columns (total 37 columns):
# tweet_id                         1971 non-null object
# timestamp                        1971 non-null datetime64[ns, UTC]
# source_x                         1971 non-null object
# text                             1971 non-null object
# expanded_urls                    1971 non-null object
# rating_numerator                 1971 non-null int64
# rating_denominator               1971 non-null int64
# name                             1447 non-null object
# dog_stage                        303 non-null object
# jpg_url                          1971 non-null object
# img_num                          1971 non-null int64
# p1                               1971 non-null object
# p1_conf                          1971 non-null float64
# p1_dog                           1971 non-null bool
# p2                               1971 non-null object
# ...

# %%
df_all.retweeted.value_counts() #value counts the retweeted.
# Out:
# False    1971
# Name: retweeted, dtype: int64

# %%
df_all.dog_stage.value_counts() #value counts the dog stages.
# Out:
# pupper           201
# doggo             63
# puppo             22
# doggo,pupper       8
# floofer            7
# doggo,puppo        1
# doggo,floofer      1
# Name: dog_stage, dtype: int64

# %%
df_all['p1'] = df_all.p1.str.capitalize()
df_all['p2'] = df_all.p2.str.capitalize()
df_all['p3'] = df_all.p3.str.capitalize()

#capitalizing each word in p1,p2 and p3

# %%
df_all.to_csv('twitter_archive_master.csv', index= False, encoding='utf-8')
#Storing the clean DataFrame in a CSV file

# %%
df_all.T
# Out:
#                                                                             0     \
# tweet_id                                                      892420643555336193
# timestamp                                              2017-08-01 16:23:56+00:00
# source_x                       <a href="http://twitter.com/download/iphone" r...
# text                           This is Phineas. He's a mystical boy. Only eve...
# expanded_urls                  https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                              13
# rating_denominator                                                            10
# name                                                                     Phineas
# dog_stage                                                                    NaN
# jpg_url                          https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# img_num                                                                        1
# ...

# %%
df_all.name.value_counts()
df_all=df_all.replace(['a','the','this','an'], np.nan)

# %%
df_all[df_all.name.notnull()]
# Out:
#                 tweet_id                 timestamp  \
# 0     892420643555336193 2017-08-01 16:23:56+00:00
# 1     892177421306343426 2017-08-01 00:17:27+00:00
# 2     891815181378084864 2017-07-31 00:18:03+00:00
# 3     891689557279858688 2017-07-30 15:58:51+00:00
# 4     891327558926688256 2017-07-29 16:00:24+00:00
# 6     890971913173991426 2017-07-28 16:27:12+00:00
# 8     890609185150312448 2017-07-27 16:25:51+00:00
# 9     890240255349198849 2017-07-26 15:59:51+00:00
# 10    890006608113172480 2017-07-26 00:31:25+00:00
# 11    889880896479866881 2017-07-25 16:11:53+00:00
# 13    889638837579907072 2017-07-25 00:10:02+00:00
# 14    889531135344209921 2017-07-24 17:02:04+00:00
# 15    889278841981685760 2017-07-24 00:19:32+00:00
# 16    888917238123831296 2017-07-23 00:22:39+00:00
# 17    888804989199671297 2017-07-22 16:56:37+00:00
# 18    888554962724278272 2017-07-22 00:23:06+00:00
# 19    888078434458587136 2017-07-20 16:49:33+00:00
# ...

# %%
df_all.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 1970
# Data columns (total 37 columns):
# tweet_id                         1971 non-null object
# timestamp                        1971 non-null datetime64[ns, UTC]
# source_x                         1971 non-null object
# text                             1971 non-null object
# expanded_urls                    1971 non-null object
# rating_numerator                 1971 non-null int64
# rating_denominator               1971 non-null int64
# name                             1378 non-null object
# dog_stage                        303 non-null object
# jpg_url                          1971 non-null object
# img_num                          1971 non-null int64
# p1                               1971 non-null object
# p1_conf                          1971 non-null float64
# p1_dog                           1971 non-null bool
# p2                               1971 non-null object
# ...

# %%
df_all.T
# Out:
#                                                                             0     \
# tweet_id                                                      892420643555336193
# timestamp                                              2017-08-01 16:23:56+00:00
# source_x                       <a href="http://twitter.com/download/iphone" r...
# text                           This is Phineas. He's a mystical boy. Only eve...
# expanded_urls                  https://twitter.com/dog_rates/status/892420643...
# rating_numerator                                                              13
# rating_denominator                                                            10
# name                                                                     Phineas
# dog_stage                                                                    NaN
# jpg_url                          https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# img_num                                                                        1
# ...

# %%
df_all.rating_denominator.unique()
# Out:
# array([ 10,  70,   7, 150,  11, 170,  20,  50,  90,  80,  40, 110, 120,
#          2])

# %%
sns.barplot(
    data= df_all,
    x= 'retweet_count',
   y = 'dog_stage',

    
    );#

# %% [markdown]
# we can see that most retweeted dogs stage was (doggo,puppo)

# %%
df_all.lang.value_counts()
# Out:
# en    1964
# nl       3
# in       2
# eu       1
# et       1
# Name: lang, dtype: int64

# %%
x= df_all.pivot_table(index=None, columns='name', values='favorite_count')
x.head()
x=x.T
x=x.sort_values('favorite_count',ascending=False)
x.head()
# Out:
#          favorite_count
# name
# Duddles        107956.0
# Stephan        107015.0
# Jamesy         106827.0
# Lilly           73397.0
# Aja             71144.0

# %% [markdown]
# we can see the top 5 favorite_count dogs

# %%
x.head().plot(kind='pie',subplots=True, figsize=(8, 8),autopct='%1.1f%%');

# %%
z= df_all.pivot_table(index=None, columns='name', values='retweet_count')
z=z.T
z=z.sort_values('retweet_count',ascending=False)
z.head()
# Out:
#          retweet_count
# name
# Stephan        56625.0
# Duddles        45849.0
# Jamesy         32883.0
# Hurley         21324.0
# Lilly          19297.0

# %%
z.head().plot(kind='pie',subplots=True, figsize=(8,8),autopct='%1.1f%%');

# %% [markdown]
# we can see the top 5 retweetd_count dogs
